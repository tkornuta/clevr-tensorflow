# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.218488
# Nearest to i: amathus, flurry, mapsto, nibble, cartel, fdi, distract, summa,
# Nearest to united: microprogramming, meander, publication, trimester, eutyches, soulful, sitcom, contrasted,
# Nearest to eight: nicknames, servant, shabda, brace, norms, esterification, widowed, republican,
# Nearest to may: patricia, musik, animists, chavez, chic, commodities, accomplice, chardin,
# Nearest to can: linden, retirement, gaff, tn, nne, cymru, bookmakers, milling,
# Nearest to more: amniotic, stockton, roadster, fanu, gras, guided, radio, regrettable,
# Nearest to if: bites, utopian, refining, ong, lockhart, wis, hervarar, excitement,
# Nearest to would: sterility, culmination, geographers, dymaxion, delineated, dms, omen, bedrooms,
# Nearest to after: disclosure, isomer, chessboard, feral, swimmer, realists, revitalization, botanic,
# Nearest to zero: concurrent, supplements, emphasises, pelias, modeled, bangs, ns, bedtime,
# Nearest to while: tactician, mining, fante, ballots, orcinus, license, audience, isolating,
# Nearest to when: ostara, transitivity, cries, filmed, examined, cva, genuinely, isma,
# Nearest to its: pkn, leone, brief, vince, lansing, condenses, folds, golfo,
# Nearest to these: brighton, aral, referring, attention, weddings, crescas, nitroglycerin, degrade,
# Nearest to also: available, deism, showtime, lash, russification, anticipating, wrongful, emi,
# Nearest to up: mouthwash, czarist, crist, mez, valentinian, arriving, romanticized, garbled,
# Average loss at step 2000: 4.366751
# Average loss at step 4000: 3.865412
# Average loss at step 6000: 3.788054
# Average loss at step 8000: 3.691436
# Average loss at step 10000: 3.617122
# Nearest to i: amathus, attainable, flurry, fdi, he, mapsto, duarte, wingers,
# Nearest to united: reprising, microprogramming, contrasted, trimester, timescale, soulful, niggle, flea,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to may: can, chavez, patricia, might, musik, animists, spherically, processions,
# Nearest to can: will, may, would, iconostasis, could, linden, must, retirement,
# Nearest to more: less, centimes, mining, gallbladder, fanu, extradition, morley, concrete,
# Nearest to if: mutant, rupiah, sternum, bites, encyclopedists, chem, freeport, headline,
# Nearest to would: could, can, will, culmination, to, mobile, dymaxion, might,
# Nearest to after: feral, botanic, pickett, isomer, became, sayles, gentrification, pleistocene,
# Nearest to zero: five, nine, six, eight, seven, three, four, two,
# Nearest to while: statehood, isolating, kotzebue, pumped, agade, counterfeiting, mining, and,
# Nearest to when: ecma, at, prompting, indian, disputes, genuinely, alonso, isma,
# Nearest to its: the, his, their, tend, entrepreneurial, lansing, beautiful, plurality,
# Nearest to these: some, referring, charred, degrade, altaic, mayonnaise, toppling, expositions,
# Nearest to also: not, it, who, disavow, meritocracy, often, yapese, sprinkled,
# Nearest to up: mouthwash, out, wealthiest, valentinian, principia, garbled, aix, telangana,
# Average loss at step 12000: 3.600931
# Average loss at step 14000: 3.568687
# Average loss at step 16000: 3.409645
# Average loss at step 18000: 3.457703
# Average loss at step 20000: 3.542956
# Nearest to i: ii, you, attainable, they, duarte, t, fdi, duquette,
# Nearest to united: reprising, supreme, publication, microprogramming, trimester, timescale, soulful, flea,
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to may: can, might, would, should, will, could, cannot, chavez,
# Nearest to can: may, will, would, could, should, must, to, iconostasis,
# Nearest to more: less, most, gallbladder, jing, mining, extradition, morley, contractions,
# Nearest to if: rupiah, activation, encyclopedists, though, chem, bites, maja, conjunctive,
# Nearest to would: could, can, will, may, might, to, should, mobile,
# Nearest to after: before, until, feral, became, undetected, when, sayles, into,
# Nearest to zero: five, six, three, four, seven, nine, eight, two,
# Nearest to while: superconducting, statehood, ballots, mining, and, mages, but, counterfeiting,
# Nearest to when: ecma, where, gamemasters, at, but, prompting, after, was,
# Nearest to its: their, his, the, her, tenacious, tend, entrepreneurial, botanical,
# Nearest to these: some, many, all, which, such, deported, both, bethany,
# Nearest to also: not, now, who, still, then, which, often, it,
# Nearest to up: out, back, mouthwash, their, him, garbled, wealthiest, valentinian,
# Average loss at step 22000: 3.501802
# Average loss at step 24000: 3.485769
# Average loss at step 26000: 3.483268
# Average loss at step 28000: 3.478721
# Average loss at step 30000: 3.504051
# Nearest to i: t, ii, they, you, attainable, swahili, allahabad, we,
# Nearest to united: reprising, supreme, publication, microprogramming, world, trimester, timescale, cygwin,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to may: can, would, should, could, will, might, cannot, must,
# Nearest to can: may, would, will, could, should, must, might, cannot,
# Nearest to more: less, most, very, overriding, gallbladder, extradition, toyota, cryptids,
# Nearest to if: though, when, activation, rupiah, above, encyclopedists, maja, bilge,
# Nearest to would: can, could, will, may, might, should, must, cannot,
# Nearest to after: before, when, until, during, sayles, patria, in, articulation,
# Nearest to zero: five, four, eight, seven, six, three, nine, two,
# Nearest to while: but, statehood, though, superconducting, mages, zionist, counterfeiting, although,
# Nearest to when: where, before, after, however, was, ecma, during, if,
# Nearest to its: their, his, the, her, tenacious, sadr, some, botanical,
# Nearest to these: some, many, such, both, all, they, which, deported,
# Nearest to also: now, often, still, which, who, it, never, not,
# Nearest to up: out, him, back, them, down, mouthwash, buchan, off,
# Average loss at step 32000: 3.501975
# Average loss at step 34000: 3.493740
# Average loss at step 36000: 3.454661
# Average loss at step 38000: 3.303878
# Average loss at step 40000: 3.430070
# Nearest to i: t, you, we, he, ii, they, attainable, it,
# Nearest to united: supreme, reprising, publication, microprogramming, trimester, timescale, world, cygwin,
# Nearest to eight: nine, seven, six, five, four, three, zero, one,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to can: will, would, may, could, must, should, might, cannot,
# Nearest to more: less, most, very, greater, toyota, overriding, too, dba,
# Nearest to if: when, though, n, for, where, zulu, encyclopedists, activation,
# Nearest to would: can, could, will, may, might, should, must, cannot,
# Nearest to after: before, during, sayles, articulation, patria, when, consolidating, until,
# Nearest to zero: seven, nine, five, eight, six, three, four, two,
# Nearest to while: though, although, but, informs, before, euphemisms, superconducting, plenipotentiary,
# Nearest to when: if, where, before, ecma, during, however, for, after,
# Nearest to its: their, his, the, tenacious, her, botanical, baskets, isotropic,
# Nearest to these: many, some, both, such, they, several, which, all,
# Nearest to also: which, still, often, now, who, never, there, therefore,
# Nearest to up: out, him, back, them, down, off, mouthwash, valentinian,
# Average loss at step 42000: 3.434724
# Average loss at step 44000: 3.457714
# Average loss at step 46000: 3.450525
# Average loss at step 48000: 3.355903
# Average loss at step 50000: 3.382841
# Nearest to i: ii, we, you, t, they, swahili, he, syrian,
# Nearest to united: publication, reprising, supreme, microprogramming, trimester, netherlands, reichenbach, meander,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to may: can, would, could, should, will, might, must, cannot,
# Nearest to can: would, may, could, will, must, should, cannot, might,
# Nearest to more: less, most, very, greater, too, better, rivalries, admixture,
# Nearest to if: when, where, though, whether, for, secretive, before, therefore,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to after: before, during, when, saw, sayles, articulation, became, until,
# Nearest to zero: eight, five, seven, four, nine, six, three, two,
# Nearest to while: though, when, although, but, before, where, and, was,
# Nearest to when: if, where, before, after, while, but, during, however,
# Nearest to its: their, his, the, her, tenacious, my, baskets, our,
# Nearest to these: some, many, both, several, those, such, various, all,
# Nearest to also: now, which, still, often, here, who, never, generally,
# Nearest to up: out, off, down, back, them, him, valentinian, send,
# Average loss at step 52000: 3.435271
# Average loss at step 54000: 3.429634
# Average loss at step 56000: 3.439026
# Average loss at step 58000: 3.398712
# Average loss at step 60000: 3.395032
# Nearest to i: ii, we, you, t, they, gyms, burrito, compare,
# Nearest to united: supreme, reprising, publication, netherlands, world, microprogramming, trimester, leveraged,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to may: can, would, could, should, will, might, must, cannot,
# Nearest to can: may, would, will, could, must, should, might, cannot,
# Nearest to more: less, most, greater, rather, very, too, smaller, highly,
# Nearest to if: when, where, though, before, then, whether, although, secretive,
# Nearest to would: could, will, may, can, should, might, must, did,
# Nearest to after: before, during, when, saw, until, sayles, abbeys, although,
# Nearest to zero: five, eight, four, six, seven, nine, three, million,
# Nearest to while: although, before, when, though, refrain, were, after, but,
# Nearest to when: if, before, where, after, while, although, during, then,
# Nearest to its: their, his, the, her, tenacious, baskets, isotropic, incorrect,
# Nearest to these: many, some, several, those, both, all, which, such,
# Nearest to also: now, still, often, generally, never, usually, here, currently,
# Nearest to up: out, down, off, back, him, them, together, send,
# Average loss at step 62000: 3.243546
# Average loss at step 64000: 3.251414
# Average loss at step 66000: 3.401577
# Average loss at step 68000: 3.400702
# Average loss at step 70000: 3.359154
# Nearest to i: ii, we, you, t, burrito, bamberg, haired, it,
# Nearest to united: supreme, reprising, publication, same, following, netherlands, trimester, surrounding,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to more: less, most, very, rather, too, greater, highly, better,
# Nearest to if: when, where, before, though, whether, although, while, however,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to after: before, during, when, until, saw, while, abbeys, principled,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to while: although, before, when, though, however, amongst, and, until,
# Nearest to when: if, where, before, while, because, after, however, was,
# Nearest to its: their, his, her, the, tenacious, incorrect, whose, averted,
# Nearest to these: such, some, those, many, several, are, various, which,
# Nearest to also: now, still, often, generally, never, which, usually, therefore,
# Nearest to up: out, off, back, down, them, him, send, bottom,
# Average loss at step 72000: 3.374388
# Average loss at step 74000: 3.346618
# Average loss at step 76000: 3.315061
# Average loss at step 78000: 3.350675
# Average loss at step 80000: 3.378152
# Nearest to i: ii, we, you, t, haired, p, they, iii,
# Nearest to united: supreme, reprising, publication, netherlands, same, trimester, flea, university,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to may: can, would, could, might, should, will, must, cannot,
# Nearest to can: could, may, would, will, must, cannot, should, might,
# Nearest to more: less, most, very, rather, greater, too, better, highly,
# Nearest to if: when, whether, before, where, though, then, since, although,
# Nearest to would: will, could, can, might, may, should, must, did,
# Nearest to after: before, during, when, saw, until, principled, abbeys, while,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to while: although, though, before, when, however, amongst, but, and,
# Nearest to when: before, if, after, where, during, while, although, though,
# Nearest to its: their, his, her, the, your, our, tenacious, my,
# Nearest to these: several, those, many, both, some, such, various, there,
# Nearest to also: now, still, often, therefore, which, generally, never, sometimes,
# Nearest to up: out, off, down, back, them, him, cac, bottom,
# Average loss at step 82000: 3.407229
# Average loss at step 84000: 3.409768
# Average loss at step 86000: 3.388329
# Average loss at step 88000: 3.356946
# Average loss at step 90000: 3.365957
# Nearest to i: we, ii, you, t, g, haired, p, woodward,
# Nearest to united: supreme, publication, reprising, netherlands, trimester, same, rest, reichenbach,
# Nearest to eight: five, nine, six, seven, four, three, zero, two,
# Nearest to may: can, could, should, would, must, might, will, cannot,
# Nearest to can: could, may, must, will, would, should, cannot, might,
# Nearest to more: less, most, very, greater, rather, too, highly, better,
# Nearest to if: when, where, before, though, although, whether, since, doesn,
# Nearest to would: will, could, might, should, can, may, must, did,
# Nearest to after: before, during, when, while, until, without, abbeys, saw,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to while: although, before, though, when, after, until, and, during,
# Nearest to when: before, if, after, where, while, although, since, until,
# Nearest to its: their, his, her, the, your, tenacious, our, whose,
# Nearest to these: several, some, many, those, such, both, various, are,
# Nearest to also: now, often, still, therefore, never, officially, generally, which,
# Nearest to up: out, off, down, back, them, him, together, send,
# Average loss at step 92000: 3.399123
# Average loss at step 94000: 3.251822
# Average loss at step 96000: 3.358853
# Average loss at step 98000: 3.240128
# Average loss at step 100000: 3.363477
# Nearest to i: we, ii, you, they, bamberg, t, he, iii,
# Nearest to united: supreme, publication, reprising, netherlands, same, trimester, reichenbach, rest,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to may: can, could, should, would, will, must, might, cannot,
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Nearest to more: less, most, greater, very, rather, better, too, smaller,
# Nearest to if: when, though, where, whether, before, doesn, although, then,
# Nearest to would: will, could, might, should, may, can, must, did,
# Nearest to after: before, during, when, until, without, although, while, despite,
# Nearest to zero: five, six, seven, eight, four, nine, three, two,
# Nearest to while: although, when, though, before, after, and, amongst, however,
# Nearest to when: if, where, while, although, before, after, though, during,
# Nearest to its: their, his, the, her, your, our, tenacious, incorrect,
# Nearest to these: several, many, some, all, those, various, were, such,
# Nearest to also: now, never, still, officially, often, generally, sometimes, usually,
# Nearest to up: off, out, down, back, them, him, bottom, together,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
