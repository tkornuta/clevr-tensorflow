# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load csv file
df = pd.read_csv('data/outfit.csv')
df
# Out:
#      outfit_id     body      style  weather           pieces
# 0            4      1;2    1;2;5;7        3  180;232;174;283
# 1            5      1;2        1;7  1;2;3;9      180;232;316
# 2            6      1;2    1;5;6;7      3;4      180;232;317
# 3            7      1;2        5;7      5;6  239;180;298;266
# 4            8      1;2      1;2;5        4      239;180;178
# 5            9      1;2    1;2;5;7      4;5  239;180;333;176
# 6           10  1;2;3;4          1    4;5;6      180;239;283
# 7           11      1;2      1;6;7      4;5      180;239;258
# 8           12      1;2      1;2;5      4;5      180;239;174
# 9           13      1;2        6;7    3;4;8  180;239;176;266
# 10          14      1;2        1;5    3;4;8  180;239;189;297
# 11          15      1;2    1;2;5;7    4;5;6      167;239;247
# 12          17      1;2    1;2;5;7      5;6      167;283;297
# 13          18      1;2        3;4    4;5;6      167;266;298
# 14          19  1;2;3;4      3;4;7      5;6      167;266;296
# 15          20      1;2        6;7      4;5      156;227;283
# 16          21      1;2      3;6;7      4;5  154;227;298;272
# 17          22      1;2      4;5;7      5;6  340;217;294;276
# 18          23      1;2  3;4;5;6;7      4;5  219;227;266;298
# 19          24      1;2    3;5;6;7      4;5          219;317
# 20          25      1;2      1;5;7      5;6  219;239;333;298
# 21          27      1;2    1;2;6;7      3;4      219;239;177
# 22          28      1;2      3;4;7    3;4;7  219;239;176;343
# 23          29  1;2;3;4        5;7    3;4;7      219;239;174
# 24          30    1;2;3        1;6    3;4;7  219;239;283;174
# 25          32      1;2        1;5      5;6  217;239;283;296
# 26          33      1;2      1;2;6    3;4;8      217;230;283
# 27          34      1;2    1;5;6;7      4;5  217;283;177;178
# 28          35      1;2        3;7      4;5      217;227;298
# 29          36      1;2      1;3;7    4;5;6      217;283;298
# ..         ...      ...        ...      ...              ...
# 512        586      1;2      5;6;7      2;3  180;148;298;316
# 513        587      1;2      5;6;7      5;6  161;275;301;276
# 514        588      1;2          1      4;5  181;239;175;283
# 515        589      1;2          1      5;6  211;235;283;297
# 516        590      1;2        6;7      4;5  180;177;239;265
# 517        591      1;2      1;6;7      2;3  192;199;283;152
# 518        592      1;2      1;4;7      5;6  180;224;298;275
# 519        594      1;2        4;6      5;6  167;265;301;329
# 520        595      1;2        6;7      3;4  204;227;149;329
# 521        596      1;2        1;7        4  180;195;334;298
# 522        597      1;2        1;7    1;2;3  180;147;247;298
# 523        598      1;2          1      5;6  181;239;298;329
# 524        599      1;2          7      3;4  180;192;323;329
# 525        600      1;2      4;6;7      5;6  156;275;296;323
# 526        601      1;2        1;7      4;5  180;224;297;247
# 527        602      1;2        1;7      3;4  180;174;301;323
# 528        603      1;2        1;7      3;4  180;196;298;321
# 529        604      1;2      1;2;7      4;5  186;224;247;298
# 530        605      1;2      4;5;7      4;5  154;174;275;323
# 531        606      1;2          1      5;6  180;239;329;283
# 532        607      1;2    1;4;5;6      5;6  154;276;323;329
# 533        608      1;2      1;2;7      3;4  180;174;296;321
# 534        609      1;2          1      5;6  183;239;298;334
# 535        610      1;2      4;6;7      5;6  156;265;298;334
# 536        611      1;2      1;5;7      5;6  180;224;296;261
# 537        612      1;2        1;7      3;4  180;150;298;321
# 538        613      3;4          4      4;5  167;333;296;269
# 539        614      1;2      4;5;6        5  226;183;296;269
# 540        616      3;4      5;6;7      4;5  232;217;296;317
# 541        617      1;2        3;4    3;4;5      8;12;70;117
#
# [542 rows x 5 columns]

# %%
# Simple "body(_type)" plot
df["body"].value_counts().plot.pie()
plt.show()

# BODY_TYPE = [1, 2, 3, 4]

# %%
# Simple "style" plot
df["style"].value_counts().plot.pie()
plt.show()

#WEATHER = {
#    1: "Freezing",
#    2: "Cold",
#    3: "Chilly",
#    4: "Fresh",
#    5: "Warm",
#    6: "Hot",
#    7: "Wind",
#    8: "Rain",
#    9: "Snow"
#}

# %%
# Simple "style" plot
df["weather"].value_counts().plot.pie()
plt.show()

#STYLE = {
#    1: "Casual",
#    2: "Grunge",
#    3: "Business",
#    4: "Glam",
#    5: "Boho",
#    6: "Artsy",
#    7: "Smart Casual"
#}
